# %%
import random
import math
import csv
import pandas as pd
import numpy as np
from scipy.stats import entropy

x_max=1 #値の最大値
x_min=-1 #値の最小値
colc_time=0.1 #計算時間
delta_t=0.001 #時間幅
loopx_list=[] #リスト用の演算結果

atom_file="test.csv"#CSVファイルURL

def x_gen(neu,x_init):
    #neu=0.1 #摩擦係数
    x=x_init #座標の初期値

    loop_count=colc_time/delta_t
    for t in range(int(loop_count)):
      real_t=t*delta_t
      f=neu*delta_t*x

      R=random.uniform(100, -100)
      y=neu*(1-x**2)*delta_t
      move_absolute=math.sqrt(abs(y))
      move=move_absolute

      if R>=0:
        move=move
        x=x-f+move

      else:
        move=-move
        x=x-f+move
      if x>x_max:
        x=x-(x-x_max)
      elif x<x_min:
        x=x+(x-x_min)

    return x #xの最終値のみ返す


def dist_gen(neu,x_init): #確率分布を出す
  x_final_list=[]
  for i in range(100):
    x=x_gen(neu,x_init)
    #print(x)
    x_final_list.append(x)
  return x_final_list


def csv_input(loopx_list, atom_file):
  print(loopx_list)
  with open(atom_file,"a")as f:
    writer=csv.writer(f)
    writer.writerow(loopx_list)


def hist_gen(data):
  data_np=np.array(data) #numpy形式というものに変換
  print(data_np)
  hist, bin_edges = np.histogram(data_np, bins=10) #元のデータを度数分布に直す（ヒストグラム）binsは分割数．
  print(hist,bin_edges) #histが元のデータの度数分布．bin_edgesが分割点．
  return hist

def entropy_calc(distribution): #（度数）分布からエントロピーを計算する関数
  probability_distribution = [float(item) for item in distribution]#浮動小数点に変換
  probability_distribution=[item/(len(probability_distribution))  for item in probability_distribution]#正規化
  ent=entropy(probability_distribution,base=2)/math.log2(len(probability_distribution)) #エントロピー算出．正規化
  #print(ent)
  return ent


for i in range(1000):
  neu=0.1
  x_init=0
  list_dist=dist_gen(neu,x_init)
  #print(list_dist)
  hist=hist_gen(list_dist)
  entropy_value=entropy_calc(hist)
  loopx_list=[neu,x_init,entropy_value]
  csv_input(loopx_list,atom_file)


#data=[x_final_list] #データを度数分布に直す
#data_np=np.array(x_final_list)
#hist, bin_edges = np.histogram(data_np, bins=10) #binsはヒストグラムの分割数
#print(hist,bin_edges)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   2.00039693e-02 -5.99009322e-02  7.98309986e-02 -1.19161242e-01
#  -2.00020470e-02 -1.19532600e-01 -5.99221500e-02  7.94789614e-02
#   1.58890966e-01 -1.19470924e-01 -1.98522515e-02 -1.19269126e-01
#   2.00439698e-02  4.00936155e-02  1.91844070e-04  5.98821759e-02
#  -4.49589919e-05 -2.42661340e-04  1.19280616e-01 -9.95878911e-02
#   7.95179749e-02  5.94151393e-02  1.39236288e-01 -5.97596106e-02
#   7.96790036e-02 -5.98949605e-02  2.00906904e-02 -3.97614505e-02
#   1.48717648e-04 -7.98509796e-02 -1.19880432e-01  2.37160547e-01
#  -3.98951944e-02  2.00718859e-02 -2.01765956e-02  1.58833387e-01
#  -9.96864330e-02 -5.97590942e-02  2.00547855e-02 -1.39222760e-01
#   9.96817756e-02 -3.97009988e-02 -5.97895057e-02  1.19432298e-01
#  -1.38991515e-01  1.97448794e-02  1.39259887e-01  1.59047333e-01
#  -9.94400848e-02 -1.59048152e-01  3.96408495e-02  1.78570324e-01
#  -5.29548785e-05  1.78793906e-01  9.98973031e-02  1.99330039e-02
# ...

# %%
import random
import math
import csv
import pandas as pd
import numpy as np
from scipy.stats import entropy

x_max=1 #値の最大値
x_min=-1 #値の最小値
colc_time=1 #計算時間
delta_t=0.001 #時間幅
loopx_list=[] #リスト用の演算結果

atom_file="data-temp.csv"#CSVファイルURL

def x_gen(neu,x_init):
    #neu=0.01 #摩擦係数
    x=x_init #座標の初期値

    loop_count=colc_time/delta_t
    for t in range(int(loop_count)):
      real_t=t*delta_t
      f=neu*delta_t*x

      R=random.uniform(100, -100)
      #print("parameter:",neu,x,delta_t)
      y=neu*(1-x**2)*delta_t
      move_absolute=math.sqrt(abs(y))
      move=move_absolute

      if R>=0:
        move=move
        x=x-f+move

      else:
        move=-move
        x=x-f+move
      if x>x_max:
        x=x_max-(x-x_max)
      elif x<x_min:
        x=x_min+(x_min-x)

    return x #xの最終値のみ返す


def dist_gen(neu,x_init): #確率分布を出す
  x_final_list=[]
  for i in range(100):
    x=x_gen(neu,x_init)
    #print(x)
    x_final_list.append(x)
  return x_final_list


def csv_input(loopx_list, atom_file):
  print(loopx_list)
  with open(atom_file,"a")as f:
    writer=csv.writer(f)
    writer.writerow(loopx_list)


def hist_gen(data):
  data_np=np.array(data) #numpy形式というものに変換
  print(data_np)
  hist, bin_edges = np.histogram(data_np, bins=10) #元のデータを度数分布に直す（ヒストグラム）binsは分割数．
  print(hist,bin_edges) #histが元のデータの度数分布．bin_edgesが分割点．
  return hist

def entropy_calc(distribution): #（度数）分布からエントロピーを計算する関数
  probability_distribution = [float(item) for item in distribution]#浮動小数点に変換
  probability_distribution=[item/(len(probability_distribution))  for item in probability_distribution]#正規化
  ent=entropy(probability_distribution,base=2)/math.log2(len(probability_distribution)) #エントロピー算出．正規化
  #print(ent)
  return ent


for i in range(20):
  for j in range (20):
    x_init=-1+i*0.1
    neu=-1+j*0.1
    x=x_gen(neu,x_init)

    list_dist=dist_gen(neu,x_init)
    #print(list_dist)
    hist=hist_gen(list_dist)
    entropy_value=entropy_calc(hist)
    loopx_list=[neu,x_init,entropy_value]
    csv_input(loopx_list,atom_file)



#data=[x_final_list] #データを度数分布に直す
#data_np=np.array(x_final_list)
#hist, bin_edges = np.histogram(data_np, bins=10) #binsはヒストグラムの分割数
#print(hist,bin_edges)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#  -2.40074378e-01 -5.90455845e-02  2.20398622e-01 -5.37801107e-01
#  -9.00802651e-01 -4.35970750e-01 -3.96443987e-01 -3.30826404e-02
#   2.36883881e-01 -8.81880379e-01 -3.18362596e-01 -5.93181475e-04
#  -3.10495277e-02 -9.59850516e-01 -2.32090940e-01 -5.60365994e-01
#   2.81919497e-01 -1.14523070e-01 -7.27484151e-01 -4.34317768e-01
#  -9.54309667e-01 -3.37282158e-01 -7.53054825e-03  3.05538857e-01
#  -4.12762040e-01 -3.48649750e-01  2.17866209e-01 -3.81894896e-01
#  -9.45408392e-01  2.55936738e-01  9.12916635e-01 -3.40350939e-01
#  -4.24238461e-01 -2.59699139e-01 -2.19940292e-01  2.85865559e-01
#  -3.92744308e-01 -8.68130303e-01  2.49686204e-01 -7.61064531e-02
#   6.37216053e-02 -5.85977385e-01 -2.41346592e-01 -4.00510177e-01
#  -7.00836986e-01 -3.42798061e-01 -4.29104268e-01 -1.39662703e-01
#  -6.70462902e-01  2.08143352e-01  3.68564972e-02 -6.89655516e-01
#  -1.16123110e-01 -1.49830706e-01 -6.54664579e-01 -1.37607741e-01]
# ...
